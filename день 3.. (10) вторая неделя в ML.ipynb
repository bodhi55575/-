# %%
# 1 словарь частот + топ-3 самых частых слов
# Исходный текст
words = ['cat', 'dog', 'cat', 'bird', 'dog', 'cat', 'fish', 'dog', 'cat']

# Собираем словарь частот
freq = {}
for word in words:
    freq[word] = freq.get(word, 0) + 1

print("Словарь частот:", freq)
# {'cat': 4, 'dog': 3, 'bird': 1, 'fish': 1}
# Out:
# Словарь частот: {'cat': 4, 'dog': 3, 'bird': 1, 'fish': 1}

# %%
# 2: Функция top_k(scores: dict, k) → список (ключ, значение) по убыванию
def top_k(scores: dict, k: int) -> list:
    """
    Возвращает список из k пар (ключ, значение), отсортированных по убыванию значений.
    """
    # Создаём список пар (значение, ключ) для сортировки
    items = [(value, key) for key, value in scores.items()]
    
    # Сортируем по убыванию
    items.sort(reverse=True)
    
    # Преобразуем обратно в (ключ, значение) и берём первые k
    return [(key, value) for value, key in items[:k]]


# Тест
freq = {'cat': 4, 'dog': 3, 'bird': 1, 'fish': 1}
top3 = top_k(freq, 3)
print("Топ-3:", top3)
# [('cat', 4), ('dog', 3), ('bird', 1)]
# Out:
# Топ-3: [('cat', 4), ('dog', 3), ('fish', 1)]

# %%
# 3: Мини-демо — изменение "течёт" во вложенном списке

# Создаём исходный вложенный список
original = [[1, 2], [3, 4]]

# Создаём поверхностную копию
shallow = original.copy()

print("До изменения:")
print("original =", original)
print("shallow  =", shallow)

# Меняем элемент во вложенном списке
shallow[0][0] = 999

print("\nПосле изменения shallow[0][0] = 999:")
print("original =", original)  # ← изменился!
print("shallow  =", shallow)

print("\nПочему?")
print("original is shallow       :", original is shallow)        # False
print("original[0] is shallow[0]:", original[0] is shallow[0])   # True ← одна и та же ссылка!
# Out:
# До изменения:
# original = [[1, 2], [3, 4]]
# shallow  = [[1, 2], [3, 4]]
#
# После изменения shallow[0][0] = 999:
# original = [[999, 2], [3, 4]]
# shallow  = [[999, 2], [3, 4]]
#
# Почему?
# original is shallow       : False
# original[0] is shallow[0]: True
