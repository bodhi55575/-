# %%
# 10 базовых примеров: числа, строки, f-строки, приведение типов, методы строк

print("1. Целое число:", 42)
print("2. Дробное число:", 3.14)
print("3. Строка:", "Привет")
print("4. Булево значение:", True)
print("5. Конкатенация:", "Привет" + " " + "мир!")
print("6. int → str:", "Мне " + str(40) + " лет")
print("7. str → int:", int("25") + 5)
s = "  ПРИВЕТ  "
print("8. strip + lower:", s.strip().lower())
print("9. Обычное деление:", 10 / 3)
print("   Целочисленное:", 10 // 3)
name = "Анна"
print(f"10. f-строка: Привет, {name}!")
# Out:
# 1. Целое число: 42
# 2. Дробное число: 3.14
# 3. Строка: Привет
# 4. Булево значение: True
# 5. Конкатенация: Привет мир!
# 6. int → str: Мне 40 лет
# 7. str → int: 30
# 8. strip + lower: привет
# 9. Обычное деление: 3.3333333333333335
#    Целочисленное: 3
# 10. f-строка: Привет, Анна!

# %%
# Функции по заданию:
# - safe_div(a, b): возвращает None при делении на ноль
# - is_palindrome(s): проверяет палиндром (игнорирует пробелы и регистр)

def safe_div(a, b):
    if b == 0:
        return None
    return a / b

def is_palindrome(s):
    cleaned = s.replace(" ", "").lower()
    return cleaned == cleaned[::-1]

# Проверка
print("safe_div:(10, 0):", safe_div(10, 0))
# используем настоящий палиндром
print("is_palindrome('А роза упала на лапу Азора'):", is_palindrome("А роза упала на лапу Азора"))  # True
print("is_palindrome('сникерс'):", is_palindrome("сникерс"))  # False
# Out:
# safe_div(10, 0): None
# is_palindrome('А роза упала на лапу Азора'): True
# is_palindrome('сникерс'): False

# %%
# Три ошибки с пояснениями (теперь они запустятся и покажут трейсбек):

print(x) # Название переменной x не определено (NameError)

# print("5" + 10) # Нельзя складывать строку и число (TypeError)
# 
# arr = [1, 2, 3]
# print(arr[10]) # Индекс выходит за границы списка (IndexError)

# Пояснение:
# Traceback показывает тип ошибки, строку и причину.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 # Три ошибки с пояснениями (теперь они запустятся и покажут трейсбек):
# ----> 3 print(x) # Название переменной x не определено (NameError)
#       5 # print("5" + 10) # Нельзя складывать строку и число (TypeError)
#       6 #
#       7 # arr = [1, 2, 3]
#    (...)     10 # Пояснение:
#      11 # Traceback показывает тип ошибки, строку и причину.
#
# NameError: name 'x' is not defined
